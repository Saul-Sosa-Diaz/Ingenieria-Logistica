# %% [markdown]
# # Problema de la mochila multiple.
# ### Autor: Saúl Sosa Díaz
#
# En este cuaderno Jupyter, resolveremos el problema de la mochila múltiple.

# %% [markdown]
# datos relevantes:
# * Conjunto de mochilas que llamaremos $K = \{1,\ldots,n\}$.
# * Conjunto de capacidades de mochilas que llamaremos $C = \{ C_i : \text{capacidad de la mochila i.} \quad \forall i \in K \}$.
# * Conjunto de objetos que llamaremos $O = \{1,\ldots,m\}$.
# * Conjunto de pesos de objetos que llamaremos $W = \{ W_j : \text{peso del objeto j.} \quad \forall j \in O \}$.
# * Conjunto de valores de objetos que llamaremos $V = \{ V_j : \text{valor del objeto j.} \quad \forall j \in O \}$.
#
# ### Modelo
# #### Variables.
# $X_{ij} = \begin{cases}
#    1 & \text{Si en la mochila } i \text{ introducimos el objeto } j \text{. }\forall i \in K \land \forall j \in V \\
#    0 & \text{Otro caso}
# \end{cases}$
# #### Función Objetivo.
# $$
# \begin{array}{ccc}
# max \sum_{i∈K}\sum_{j∈O} v_{i} * X_{ij}& \\&
# \end{array}
# $$
# #### Restricciones.
# $$
# \begin{array}{ccc}
# &  \sum_{i∈K} X_{gt} = 1 & \forall g \in G & \text{  Cada grupo tiene asignado un trabajo.} \\
# &  \sum_{g∈G} X_{gt} <= 1 & \forall t \in T & \text{  Un trabajo puede estar asignado como mucho a un grupo.}\\
# \end{array}
# $$

# %% [markdown]
# ### Resolvemos el modelo.

# %% [markdown]
# #### Importamos las librerías necesarias.

# %%
import Pkg
Pkg.add("JuMP")
Pkg.add("GLPK")

using JuMP, GLPK, Random
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`

# %% [markdown]
# #### Introducimos los datos.

# %% [markdown]
# Si se quisiera introducir datos de verdad bastaría con cambiar los datos de la siguiente celda.
# Recordar que $P_{ij}$ indica la prioridad del grupo i por hacer el trabajo j.

# %%
K = 29       # número de Mochilas
O = 100        # número de objetos

Random.seed!(1234)
C = rand(1:10, K) # capacidades de las mochila

W = rand(1:10, O) # pesos de los objetos
V = rand(1:10, O) # valores de los objetos


# Mostrar Mochilas
for i in 1:K
    println("La mochila $i tiene una capacidad de ", C[i])
end
println()
# Mostrar objetos
for j in 1:O
    println("El objeto $j tiene un peso de ", W[j], " y un valor de ", V[j])
end
# Out:
# La mochila 1 tiene una capacidad de 4
# La mochila 2 tiene una capacidad de 6
# La mochila 3 tiene una capacidad de 3
# La mochila 4 tiene una capacidad de 9
# La mochila 5 tiene una capacidad de 4
# La mochila 6 tiene una capacidad de 4
# La mochila 7 tiene una capacidad de 10
# La mochila 8 tiene una capacidad de 8
# La mochila 9 tiene una capacidad de 5
# La mochila 10 tiene una capacidad de 8
# La mochila 11 tiene una capacidad de 6
# La mochila 12 tiene una capacidad de 8
# La mochila 13 tiene una capacidad de 1
# La mochila 14 tiene una capacidad de 2
# La mochila 15 tiene una capacidad de 5
# La mochila 16 tiene una capacidad de 7
# La mochila 17 tiene una capacidad de 10
# La mochila 18 tiene una capacidad de 7
# La mochila 19 tiene una capacidad de 10
# La mochila 20 tiene una capacidad de 8
# La mochila 21 tiene una capacidad de 2
# La mochila 22 tiene una capacidad de 5
# La mochila 23 tiene una capacidad de 6
# La mochila 24 tiene una capacidad de 3
# La mochila 25 tiene una capacidad de 7
# La mochila 26 tiene una capacidad de 3
# La mochila 27 tiene una capacidad de 2
# La mochila 28 tiene una capacidad de 7
# La mochila 29 tiene una capacidad de 7
#
# El objeto 1 tiene un peso de 8 y un valor de 6
# El objeto 2 tiene un peso de 6 y un valor de 6
# El objeto 3 tiene un peso de 4 y un valor de 9
# El objeto 4 tiene un peso de 2 y un valor de 8
# El objeto 5 tiene un peso de 10 y un valor de 8
# El objeto 6 tiene un peso de 6 y un valor de 1
# El objeto 7 tiene un peso de 7 y un valor de 9
# El objeto 8 tiene un peso de 6 y un valor de 6
# El objeto 9 tiene un peso de 1 y un valor de 3
# El objeto 10 tiene un peso de 8 y un valor de 1
# El objeto 11 tiene un peso de 1 y un valor de 7
# El objeto 12 tiene un peso de 9 y un valor de 5
# El objeto 13 tiene un peso de 4 y un valor de 5
# El objeto 14 tiene un peso de 8 y un valor de 4
# El objeto 15 tiene un peso de 3 y un valor de 9
# El objeto 16 tiene un peso de 6 y un valor de 9
# El objeto 17 tiene un peso de 3 y un valor de 10
# El objeto 18 tiene un peso de 3 y un valor de 1
# El objeto 19 tiene un peso de 10 y un valor de 7
# El objeto 20 tiene un peso de 9 y un valor de 10
# El objeto 21 tiene un peso de 8 y un valor de 5
# El objeto 22 tiene un peso de 5 y un valor de 7
# El objeto 23 tiene un peso de 9 y un valor de 2
# El objeto 24 tiene un peso de 6 y un valor de 4
# El objeto 25 tiene un peso de 10 y un valor de 5
# El objeto 26 tiene un peso de 9 y un valor de 8
# El objeto 27 tiene un peso de 5 y un valor de 9
# El objeto 28 tiene un peso de 10 y un valor de 9
# El objeto 29 tiene un peso de 6 y un valor de 4
# El objeto 30 tiene un peso de 8 y un valor de 6
# El objeto 31 tiene un peso de 2 y un valor de 9
# El objeto 32 tiene un peso de 4 y un valor de 7
# El objeto 33 tiene un peso de 6 y un valor de 2
# El objeto 34 tiene un peso de 2 y un valor de 8
# El objeto 35 tiene un peso de 4 y un valor de 6
# El objeto 36 tiene un peso de 7 y un valor de 6
# El objeto 37 tiene un peso de 4 y un valor de 7
# El objeto 38 tiene un peso de 8 y un valor de 5
# El objeto 39 tiene un peso de 1 y un valor de 9
# El objeto 40 tiene un peso de 2 y un valor de 3
# El objeto 41 tiene un peso de 6 y un valor de 3
# El objeto 42 tiene un peso de 1 y un valor de 4
# El objeto 43 tiene un peso de 6 y un valor de 1
# El objeto 44 tiene un peso de 10 y un valor de 8
# El objeto 45 tiene un peso de 2 y un valor de 2
# El objeto 46 tiene un peso de 4 y un valor de 1
# El objeto 47 tiene un peso de 9 y un valor de 8
# El objeto 48 tiene un peso de 7 y un valor de 5
# El objeto 49 tiene un peso de 5 y un valor de 9
# El objeto 50 tiene un peso de 10 y un valor de 9
# El objeto 51 tiene un peso de 1 y un valor de 1
# El objeto 52 tiene un peso de 4 y un valor de 3
# El objeto 53 tiene un peso de 9 y un valor de 10
# El objeto 54 tiene un peso de 8 y un valor de 10
# El objeto 55 tiene un peso de 10 y un valor de 6
# El objeto 56 tiene un peso de 5 y un valor de 5
# El objeto 57 tiene un peso de 2 y un valor de 8
# El objeto 58 tiene un peso de 10 y un valor de 2
# El objeto 59 tiene un peso de 7 y un valor de 7
# El objeto 60 tiene un peso de 9 y un valor de 8
# El objeto 61 tiene un peso de 4 y un valor de 9
# El objeto 62 tiene un peso de 8 y un valor de 10
# El objeto 63 tiene un peso de 5 y un valor de 6
# El objeto 64 tiene un peso de 4 y un valor de 7
# El objeto 65 tiene un peso de 9 y un valor de 5
# El objeto 66 tiene un peso de 2 y un valor de 10
# El objeto 67 tiene un peso de 5 y un valor de 7
# El objeto 68 tiene un peso de 6 y un valor de 6
# El objeto 69 tiene un peso de 5 y un valor de 6
# El objeto 70 tiene un peso de 5 y un valor de 1
# El objeto 71 tiene un peso de 10 y un valor de 9
# El objeto 72 tiene un peso de 5 y un valor de 5
# El objeto 73 tiene un peso de 5 y un valor de 8
# El objeto 74 tiene un peso de 1 y un valor de 2
# El objeto 75 tiene un peso de 8 y un valor de 6
# El objeto 76 tiene un peso de 2 y un valor de 4
# El objeto 77 tiene un peso de 8 y un valor de 2
# El objeto 78 tiene un peso de 6 y un valor de 7
# El objeto 79 tiene un peso de 2 y un valor de 1
# El objeto 80 tiene un peso de 8 y un valor de 6
# El objeto 81 tiene un peso de 7 y un valor de 7
# El objeto 82 tiene un peso de 3 y un valor de 6
# El objeto 83 tiene un peso de 3 y un valor de 6
# El objeto 84 tiene un peso de 5 y un valor de 7
# El objeto 85 tiene un peso de 2 y un valor de 3
# El objeto 86 tiene un peso de 1 y un valor de 3
# El objeto 87 tiene un peso de 9 y un valor de 7
# El objeto 88 tiene un peso de 4 y un valor de 10
# El objeto 89 tiene un peso de 2 y un valor de 7
# El objeto 90 tiene un peso de 3 y un valor de 8
# El objeto 91 tiene un peso de 4 y un valor de 1
# El objeto 92 tiene un peso de 7 y un valor de 4
# El objeto 93 tiene un peso de 8 y un valor de 1
# El objeto 94 tiene un peso de 3 y un valor de 3
# El objeto 95 tiene un peso de 7 y un valor de 8
# El objeto 96 tiene un peso de 2 y un valor de 9
# El objeto 97 tiene un peso de 10 y un valor de 6
# El objeto 98 tiene un peso de 8 y un valor de 5
# El objeto 99 tiene un peso de 1 y un valor de 3
# El objeto 100 tiene un peso de 9 y un valor de 7

# %% [markdown]
# #### Definimos el modelo.

# %%
model = Model(GLPK.Optimizer)
set_silent(model)

# Definir variables
@variable(model, X[1:K,1:O], binary=true)
# Definir función objetivo
@objective(model, Max, sum(X[i, j] * V[j] for i in 1:K, j in 1:O))
@constraint(model, p[j=1:O] , sum(X[:,j]) <= 1 ) # Cada objeto solo puede estar en una mochila.
@constraint(model, c[i=1:K] , sum(X[i,j] * W[j] for j in 1:O) <= C[i] ) # Cada mochila tiene que tener un peso menor que su capacidad.
# Out:
# 29-element Vector{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape}}:
#  c[1] : 8 X[1,1] + 6 X[1,2] + 4 X[1,3] + 2 X[1,4] + 10 X[1,5] + 6 X[1,6] + 7 X[1,7] + 6 X[1,8] + X[1,9] + 8 X[1,10] + X[1,11] + 9 X[1,12] + 4 X[1,13] + 8 X[1,14] + 3 X[1,15] + 6 X[1,16] + 3 X[1,17] + 3 X[1,18] + 10 X[1,19] + 9 X[1,20] + 8 X[1,21] + 5 X[1,22] + 9 X[1,23] + 6 X[1,24] + 10 X[1,25] + 9 X[1,26] + 5 X[1,27] + 10 X[1,28] + 6 X[1,29] + 8 X[1,30] + 2 X[1,31] + 4 X[1,32] + 6 X[1,33] + 2 X[1,34] + 4 X[1,35] + 7 X[1,36] + 4 X[1,37] + 8 X[1,38] + X[1,39] + 2 X[1,40] + 6 X[1,41] + X[1,42] + 6 X[1,43] + 10 X[1,44] + 2 X[1,45] + 4 X[1,46] + 9 X[1,47] + 7 X[1,48] + 5 X[1,49] + 10 X[1,50] + X[1,51] + 4 X[1,52] + 9 X[1,53] + 8 X[1,54] + 10 X[1,55] + 5 X[1,56] + 2 X[1,57] + 10 X[1,58] + 7 X[1,59] + 9 X[1,60] + 4 X[1,61] + 8 X[1,62] + 5 X[1,63] + 4 X[1,64] + 9 X[1,65] + 2 X[1,66] + 5 X[1,67] + 6 X[1,68] + 5 X[1,69] + 5 X[1,70] + 10 X[1,71] + 5 X[1,72] + 5 X[1,73] + X[1,74] + 8 X[1,75] + 2 X[1,76] + 8 X[1,77] + 6 X[1,78] + 2 X[1,79] + 8 X[1,80] + 7 X[1,81] + 3 X[1,82] + 3 X[1,83] + 5 X[1,84] + 2 X[1,85] + X[1,86] + 9 X[1,87] + 4 X[1,88] + 2 X[1,89] + 3 X[1,90] + 4 X[1,91] + 7 X[1,92] + 8 X[1,93] + 3 X[1,94] + 7 X[1,95] + 2 X[1,96] + 10 X[1,97] + 8 X[1,98] + X[1,99] + 9 X[1,100] ≤ 4
#  c[2] : 8 X[2,1] + 6 X[2,2] + 4 X[2,3] + 2 X[2,4] + 10 X[2,5] + 6 X[2,6] + 7 X[2,7] + 6 X[2,8] + X[2,9] + 8 X[2,10] + X[2,11] + 9 X[2,12] + 4 X[2,13] + 8 X[2,14] + 3 X[2,15] + 6 X[2,16] + 3 X[2,17] + 3 X[2,18] + 10 X[2,19] + 9 X[2,20] + 8 X[2,21] + 5 X[2,22] + 9 X[2,23] + 6 X[2,24] + 10 X[2,25] + 9 X[2,26] + 5 X[2,27] + 10 X[2,28] + 6 X[2,29] + 8 X[2,30] + 2 X[2,31] + 4 X[2,32] + 6 X[2,33] + 2 X[2,34] + 4 X[2,35] + 7 X[2,36] + 4 X[2,37] + 8 X[2,38] + X[2,39] + 2 X[2,40] + 6 X[2,41] + X[2,42] + 6 X[2,43] + 10 X[2,44] + 2 X[2,45] + 4 X[2,46] + 9 X[2,47] + 7 X[2,48] + 5 X[2,49] + 10 X[2,50] + X[2,51] + 4 X[2,52] + 9 X[2,53] + 8 X[2,54] + 10 X[2,55] + 5 X[2,56] + 2 X[2,57] + 10 X[2,58] + 7 X[2,59] + 9 X[2,60] + 4 X[2,61] + 8 X[2,62] + 5 X[2,63] + 4 X[2,64] + 9 X[2,65] + 2 X[2,66] + 5 X[2,67] + 6 X[2,68] + 5 X[2,69] + 5 X[2,70] + 10 X[2,71] + 5 X[2,72] + 5 X[2,73
#  c[29] : 8 X[29,1] + 6 X[29,2] + 4 X[29,3] + 2 X[29,4] + 10 X[29,5] + 6 X[29,6] + 7 X[29,7] + 6 X[29,8] + X[29,9] + 8 X[29,10] + X[29,11] + 9 X[29,12] + 4 X[29,13] + 8 X[29,14] + 3 X[29,15] + 6 X[29,16] + 3 X[29,17] + 3 X[29,18] + 10 X[29,19] + 9 X[29,20] + 8 X[29,21] + 5 X[29,22] + 9 X[29,23] + 6 X[29,24] + 10 X[29,25] + 9 X[29,26] + 5 X[29,27] + 10 X[29,28] + 6 X[29,29] + 8 X[29,30] + 2 X[29,31] + 4 X[29,32] + 6 X[29,33] + 2 X[29,34] + 4 X[29,35] + 7 X[29,36] + 4 X[29,37] + 8 X[29,38] + X[29,39] + 2 X[29,40] + 6 X[29,41] + X[29,42] + 6 X[29,43] + 10 X[29,44] + 2 X[29,45] + 4 X[29,46] + 9 X[29,47] + 7 X[29,48] + 5 X[29,49] + 10 X[29,50] + X[29,51] + 4 X[29,52] + 9 X[29,53] + 8 X[29,54] + 10 X[29,55] + 5 X[29,56] + 2 X[29,57] + 10 X[29,58] + 7 X[29,59] + 9 X[29,60] + 4 X[29,61] + 8 X[29,62] + 5 X[29,63] + 4 X[29,64] + 9 X[29,65] + 2 X[29,66] + 5 X[29,67] + 6 X[29,68] + 5 X[29,69] + 5 X[29,70] + 10 X[29,71] + 5 X[29,72] + 5 X[29,73] + X[29,74] + 8 X[29,75] + 2 X[29,76] + 8 X[29,77] + 6 X[29,78] + 2 X[29,79] + 8 X[29,80] + 7 X[29,81] + 3 X[29,82] + 3 X[29,83] + 5 X[29,84] + 2 X[29,85] + X[29,86] + 9 X[29,87] + 4 X[29,88] + 2 X[29,89] + 3 X[29,90] + 4 X[29,91] + 7 X[29,92] + 8 X[29,93] + 3 X[29,94] + 7 X[29,95] + 2 X[29,96] + 10 X[29,97] + 8 X[29,98] + X[29,99] + 9 X[29,100] ≤ 7

# %% [markdown]
# #### Resolvemos el modelo.

# %%
optimize!(model)

# %% [markdown]
# #### Mostramos el resultado.

# %%
objetive = objective_value(model)
println("El valor máximo que se puede obtener es: ", objetive)
println("El modelo ha tardado en resolverse: ",solve_time(model))
println()

for i in 1:K
    println("La mochila $i tiene una capacidad de ", C[i], " Kg.")
    println("Los objetos que contiene son: ")
    ocupado = 0
    for j in 1:O
        if value(X[i,j]) == 1
            println("    El objeto $j tiene un peso de ", W[j], " Kg y un valor de ", V[j], " €.")
            ocupado += W[j]
        end
    end
    println("    El peso total de la mochila es de ", ocupado, " Kg.")
    println()
end
# Out:
# El valor máximo que se puede obtener es: 323.0
# El modelo ha tardado en resolverse: 0.41814208030700684
#
# La mochila 1 tiene una capacidad de 4 Kg.
# Los objetos que contiene son:
#     El objeto 88 tiene un peso de 4 Kg y un valor de 10 €.
#     El peso total de la mochila es de 4 Kg.
#
# La mochila 2 tiene una capacidad de 6 Kg.
# Los objetos que contiene son:
#     El objeto 39 tiene un peso de 1 Kg y un valor de 9 €.
#     El objeto 69 tiene un peso de 5 Kg y un valor de 6 €.
#     El peso total de la mochila es de 6 Kg.
#
# La mochila 3 tiene una capacidad de 3 Kg.
# Los objetos que contiene son:
#     El objeto 11 tiene un peso de 1 Kg y un valor de 7 €.
#     El objeto 76 tiene un peso de 2 Kg y un valor de 4 €.
#     El peso total de la mochila es de 3 Kg.
#
# La mochila 4 tiene una capacidad de 9 Kg.
# Los objetos que contiene son:
#     El objeto 53 tiene un peso de 9 Kg y un valor de 10 €.
#     El peso total de la mochila es de 9 Kg.
#
# La mochila 5 tiene una capacidad de 4 Kg.
# Los objetos que contiene son:
#     El objeto 32 tiene un peso de 4 Kg y un valor de 7 €.
#     El peso total de la mochila es de 4 Kg.
#
# La mochila 6 tiene una capacidad de 4 Kg.
# Los objetos que contiene son:
#     El objeto 13 tiene un peso de 4 Kg y un valor de 5 €.
#     El peso total de la mochila es de 4 Kg.
#
# La mochila 7 tiene una capacidad de 10 Kg.
# Los objetos que contiene son:
#     El objeto 62 tiene un peso de 8 Kg y un valor de 10 €.
#     El objeto 96 tiene un peso de 2 Kg y un valor de 9 €.
#     El peso total de la mochila es de 10 Kg.
#
# La mochila 8 tiene una capacidad de 8 Kg.
# Los objetos que contiene son:
#     El objeto 54 tiene un peso de 8 Kg y un valor de 10 €.
#     El peso total de la mochila es de 8 Kg.
#
# La mochila 9 tiene una capacidad de 5 Kg.
# Los objetos que contiene son:
#     El objeto 73 tiene un peso de 5 Kg y un valor de 8 €.
#     El peso total de la mochila es de 5 Kg.
#
# La mochila 10 tiene una capacidad de 8 Kg.
# Los objetos que contiene son:
#     El objeto 67 tiene un peso de 5 Kg y un valor de 7 €.
#     El objeto 90 tiene un peso de 3 Kg y un valor de 8 €.
#     El peso total de la mochila es de 8 Kg.
#
# La mochila 11 tiene una capacidad de 6 Kg.
# Los objetos que contiene son:
#     El objeto 82 tiene un peso de 3 Kg y un valor de 6 €.
#     El objeto 83 tiene un peso de 3 Kg y un valor de 6 €.
#     El peso total de la mochila es de 6 Kg.
#
# La mochila 12 tiene una capacidad de 8 Kg.
# Los objetos que contiene son:
#     El objeto 66 tiene un peso de 2 Kg y un valor de 10 €.
#     El objeto 78 tiene un peso de 6 Kg y un valor de 7 €.
#     El peso total de la mochila es de 8 Kg.
#
# La mochila 13 tiene una capacidad de 1 Kg.
# Los objetos que contiene son:
#     El objeto 9 tiene un peso de 1 Kg y un valor de 3 €.
#     El peso total de la mochila es de 1 Kg.
#
# La mochila 14 tiene una capacidad de 2 Kg.
# Los objetos que contiene son:
#     El objeto 57 tiene un peso de 2 Kg y un valor de 8 €.
#     El peso total de la mochila es de 2 Kg.
#
# La mochila 15 tiene una capacidad de 5 Kg.
# Los objetos que contiene son:
#     El objeto 49 tiene un peso de 5 Kg y un valor de 9 €.
#     El peso total de la mochila es de 5 Kg.
#
# La mochila 16 tiene una capacidad de 7 Kg.
# Los objetos que contiene son:
#     El objeto 95 tiene un peso de 7 Kg y un valor de 8 €.
#     El peso total de la mochila es de 7 Kg.
#
# La mochila 17 tiene una capacidad de 10 Kg.
# Los objetos que contiene son:
#     El objeto 3 tiene un peso de 4 Kg y un valor de 9 €.
#     El objeto 37 tiene un peso de 4 Kg y un valor de 7 €.
#     El objeto 45 tiene un peso de 2 Kg y un valor de 2 €.
#     El peso total de la mochila es de 10 Kg.
#
# La mochila 18 tiene una capacidad de 7 Kg.
# Los objetos que contiene son:
#     El objeto 35 tiene un peso de 4 Kg y un valor de 6 €.
#     El objeto 74 tiene un peso de 1 Kg y un valor de 2 €.
#     El objeto 86 tiene un peso de 1 Kg y un valor de 3 €.
#     El objeto 99 tiene un peso de 1 Kg y un valor de 3 €.
#     El peso total de la mochila es de 7 Kg.
#
# La mochila 19 tiene una capacidad de 10 Kg.
# Los objetos que contiene son:
#     El objeto 27 tiene un peso de 5 Kg y un valor de 9 €.
#     El objeto 63 tiene un peso de 5 Kg y un valor de 6 €.
#     El peso total de la mochila es de 10 Kg.
#
# La mochila 20 tiene una capacidad de 8 Kg.
# Los objetos que contiene son:
#     El objeto 16 tiene un peso de 6 Kg y un valor de 9 €.
#     El objeto 85 tiene un peso de 2 Kg y un valor de 3 €.
#     El peso total de la mochila es de 8 Kg.
#
# La mochila 21 tiene una capacidad de 2 Kg.
# Los objetos que contiene son:
#     El objeto 40 tiene un peso de 2 Kg y un valor de 3 €.
#     El peso total de la mochila es de 2 Kg.
#
# La mochila 22 tiene una capacidad de 5 Kg.
# Los objetos que contiene son:
#     El objeto 22 tiene un peso de 5 Kg y un valor de 7 €.
#     El peso total de la mochila es de 5 Kg.
#
# La mochila 23 tiene una capacidad de 6 Kg.
# Los objetos que contiene son:
#     El objeto 34 tiene un peso de 2 Kg y un valor de 8 €.
#     El objeto 64 tiene un peso de 4 Kg y un valor de 7 €.
#     El peso total de la mochila es de 6 Kg.
#
# La mochila 24 tiene una capacidad de 3 Kg.
# Los objetos que contiene son:
#     El objeto 15 tiene un peso de 3 Kg y un valor de 9 €.
#     El peso total de la mochila es de 3 Kg.
#
# La mochila 25 tiene una capacidad de 7 Kg.
# Los objetos que contiene son:
#     El objeto 31 tiene un peso de 2 Kg y un valor de 9 €.
#     El objeto 84 tiene un peso de 5 Kg y un valor de 7 €.
#     El peso total de la mochila es de 7 Kg.
#
# La mochila 26 tiene una capacidad de 3 Kg.
# Los objetos que contiene son:
#     El objeto 17 tiene un peso de 3 Kg y un valor de 10 €.
#     El peso total de la mochila es de 3 Kg.
#
# La mochila 27 tiene una capacidad de 2 Kg.
# Los objetos que contiene son:
#     El objeto 4 tiene un peso de 2 Kg y un valor de 8 €.
#     El peso total de la mochila es de 2 Kg.
#
# La mochila 28 tiene una capacidad de 7 Kg.
# Los objetos que contiene son:
#     El objeto 7 tiene un peso de 7 Kg y un valor de 9 €.
#     El peso total de la mochila es de 7 Kg.
#
# La mochila 29 tiene una capacidad de 7 Kg.
# Los objetos que contiene son:
#     El objeto 42 tiene un peso de 1 Kg y un valor de 4 €.
#     El objeto 61 tiene un peso de 4 Kg y un valor de 9 €.
#     El objeto 89 tiene un peso de 2 Kg y un valor de 7 €.
#     El peso total de la mochila es de 7 Kg.
